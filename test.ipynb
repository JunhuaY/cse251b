# %%
import numpy as np
import pandas as pd

# %%
df2 = pd.read_csv('new_train_proteins_filled.csv')
df
# Out:
#       Unnamed: 0  patient_id  visit_month    O00391    O00533   O00584  \
# 0              0          55            0  11254.30  732430.0  39585.8
# 1              1          55            6  13163.60  630465.0  35220.8
# 2              2          55           12  15257.60  815083.0  41650.9
# 3              3          55           36  13530.80  753832.0  43048.9
# 4              4        1517            0  11648.90  419015.0  35053.8
# ...          ...         ...          ...       ...       ...      ...
# 1108        1108        7508           48   9459.04  599910.0  39554.4
# 1109        1109       12931           24  13045.70  473983.0  26181.8
# 1110        1110       12931           36  10105.70  462621.0  23895.3
# 1111        1111       12931           48  14611.60  593385.0  25331.3
# 1112        1112       12931           60  13686.40  594355.0  25997.8
#
#        O14498    O14773   O14791    O15240  ...    Q9HDC9   Q9NQ79    Q9NYU2  \
# ...
